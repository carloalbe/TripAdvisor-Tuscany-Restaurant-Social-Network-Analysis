# %%
import pandas as pd
import numpy as np
import json 
import math
import collections
import networkx as nx
from matplotlib import pyplot as plt

# %%
filename = 'C:/Users/io/Desktop/info_er.json'

# %% [markdown]
# # Erdős–Rényi Network

# %%
G = nx.read_adjlist('C:/Users/io/Desktop/ER.adjlist')

# %%
N = len(G.nodes)
L = len(G.edges)
density = nx.density(G)
print(N,L)
print(density)
# Out:
# 15077 137080
# 0.0012061547397983357

# %%
data = dict()
data['name'] = 'Erdős–Rényi'
data['N_nodes'] = N
data['N_edges'] = L
data['density'] = density
with open(filename,'w') as jf:
    json.dump(data,jf)

# %% [markdown]
# ## Degree distribution analysis

# %%
degrees = [(n,d) for n, d in G.degree()]

# %%
with open(filename,'r') as jf:
    data = json.load(jf)

data['degrees'] = degrees

with open(filename,'w') as jf:
    json.dump(data,jf)

# %% [markdown]
# ## Connected components analysis

# %%
components =  [c for c in sorted(nx.connected_components(G), key=len, reverse=True)]
avg_size = np.average([len(c) for c in components])
print('average componets size: ', avg_size)
print([len(c) for c in components[:7]],'etc...')
# Out:
# average componets size:  15077.0
# [15077] etc...

# %%
with open(filename,'r') as jf:
    data = json.load(jf)

data['components'] = [len(c) for c in components]

with open(filename,'w') as jf:
    json.dump(data,jf)

# %%
C = G.subgraph(components[0])

# %%
with open (filename,'r') as jf:
    data=json.load(jf)
    
print (data)
# Out:
# {'name': 'Erdős–Rényi', 'N_nodes': 15077, 'N_edges': 137080, 'density': 0.0012061547397983357, 'degrees': [['0', 14], ['894', 14], ['2891', 15], ['3361', 16], ['4582', 19], ['5725', 15], ['6237', 17], ['7030', 20], ['8595', 14], ['9006', 16], ['9273', 20], ['11204', 14], ['11561', 19], ['12477', 16], ['14101', 22], ['1', 15], ['2052', 13], ['2382', 21], ['5824', 18], ['6591', 18], ['6806', 17], ['7537', 16], ['7597', 20], ['8421', 14], ['9223', 30], ['9541', 16], ['10443', 16], ['11995', 19], ['13656', 18], ['14008', 14], ['14307', 26], ['2', 21], ['2410', 24], ['2624', 23], ['3317', 19], ['4376', 14], ['6580', 25], ['6814', 14], ['7009', 16], ['7047', 15], ['7706', 19], ['8858', 18], ['8945', 22], ['9899', 15], ['9953', 22], ['11615', 18], ['11803', 10], ['12214', 20], ['12963', 18], ['13806', 22], ['14432', 21], ['14615', 22], ['15016', 32], ['3', 20], ['381', 26], ['544', 15], ['877', 23], ['1418', 18], ['4010', 16], ['4631', 19], ['6249', 16], ['6261', 17], ['6547', 21], ['7655', 18], ['7910', 20], ['9774', 26], ['10121', 16], ['10451', 19], ['10965', 24], ['11567', 14], ['12741', 17], ['13796', 24], ['14521', 31], ['14956', 17], ['4', 19], ['157', 20], ['219', 23], ['2196', 21], ['2411', 11], ['2860', 25], ['4634', 22], ['7139', 23], ['8651', 21], ['8954', 20], ['8998', 21], ['9414', 14], ['10917', 10], ['11187', 22], ['11473', 21], ['12344', 17], ['12570', 16], ['12841', 21], ['13406', 18], ['13509', 16], ['5', 24], ['267', 22], ['811', 25], ['1373', 19], ['1960', 28], ['2186', 14], ['2915', 16], ['3144', 17], ['3425', 20], ['4585', 27], ['4615', 21], ['5207', 13], ['5306', 28], ['6712', 15], ['7425', 13], ['7494', 17], ['8675', 25], ['11347', 17], ['11359', 20], ['12067', 19], ['12232', 22], ['13573', 16], ['13618', 21], ['14518', 20], ['14574', 20], ['6', 16], ['166', 22], ['559', 27], ['1681', 18], ['2491', 25], ['6044', 25], ['6897', 14], ['7874', 18], ['8673', 19], ['9117', 19], ['9338', 17], ['9387', 18], ['10924', 23], ['11800', 21], ['12439', 19], ['12571', 15], ['12734', 19], ['7', 16], ['3491', 18], ['3714', 19], ['3792', 22], ['3863', 17], ['4647', 25], ['4665', 22], ['6755', 15], ['6761', 13], ['6941', 21], ['7416', 25], ['9145', 9], ['11117', 27], ['12756', 13], ['13548', 19], ['14501', 26], ['14646', 24], ['8', 16], ['1238', 22], ['1349', 24], ['1861', 20], ['2007', 22], ['2741', 23], ['4234', 22], ['5819', 27], ['6405', 14], ['6984', 23], ['8910', 19], ['9646', 25], ['10963', 22], ['12158', 23], ['12638', 20], ['12855', 19], ['9', 14], ['213', 16], ['1374', 18], ['3119', 14], ['3402', 13], ['4137', 18], ['4504', 17], ['5963', 25], ['6575', 21], ['6662', 16], ['8728', 21], ['8882', 23], ['10521', 23], ['10721', 21], ['12287', 26], ['10', 18], ['1467', 22], ['2686', 26], ['3127', 17], ['3281', 23], ['3354', 10], ['3603', 27], ['4300', 21], ['4338', 19], ['5282', 23], ['5659', 31], ['6409', 19], ['8594', 17], ['9237', 21], ['10925', 18], ['11374', 12], ['11481', 21], ['14409', 23], ['14551', 24], ['11', 13], ['1458', 14], ['2547', 13], ['4354', 18], ['7216', 25], ['8596', 17], ['9354', 20], ['9802', 10], ['10993', 26], ['11462', 22], ['12432', 17], ['13303', 22], ['14287', 20], ['14537', 16], ['12', 23], ['117', 19], ['256', 18], ['680', 22], ['1001', 14], ['1332', 23], ['1530', 19], ['2356', 23], ['2525', 13], ['3132', 20], ['3785', 21], ['4799', 19], ['5510', 12], ['5818', 23], ['6027', 16], ['8504', 25], ['8590', 19], ['10492', 18], ['11087', 27], ['11193', 16], ['11398', 14], ['12469', 18], ['12760', 18], ['13464', 27], ['13', 18], ['46', 23], ['564', 20], ['641', 20], ['1906', 20], ['1969', 14], ['2140', 15], ['4076', 19], ['4874', 17], ['6298', 18], ['6412', 23], ['6530', 20], ['6909', 17], ['8432', 24], ['9278', 22], ['11020', 20], ['11545', 18], ['12213', 22], ['12464', 21], ['14', 14], ['532', 21], ['2228', 21], ['3612', 20], ['5696', 17], ['8171', 22], ['8569', 19], ['8591', 19], ['11259', 25], ['12759', 16], ['12774', 16], ['14251', 20], ['14687', 21], ['14801', 12], ['14819', 27], ['15', 24], ['66 ...

# %% [markdown]
# ## Path analysis

# %%
avg_shortest_path = nx.average_shortest_path_length(C)

# %%
data['avg_shortest_path'] = avg_shortest_path

with open(filename,'w') as jf:
    json.dump(data,jf)

# %%
diameter= nx.diameter(C)

# %%
with open(filename, 'r') as jf:
    data=json.load(jf)

data['diameter']=diameter
with open(filename, 'w') as jf:
      json.dump(data,jf)

# %% [markdown]
# ## Clustering Coefficient, Density analysis

# %%
clusterings = nx.clustering(G)

with open(filename,'r') as jf:
    data = json.load(jf)

data['clusterings'] =clusterings 

with open(filename,'w') as jf:
    json.dump(data,jf)

# %%
average_clustering=nx.average_clustering(G)

# %%
with open(filename,'r') as jf:
    data = json.load(jf)

data['average clusterings'] =average_clustering

with open(filename,'w') as jf:
    json.dump(data,jf)
